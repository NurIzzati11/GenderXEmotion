# %% [markdown]
# <a href="https://colab.research.google.com/github/NurIzzati11/GenderXEmotion/blob/main/GenderXEmotion(Emotion)EXPERIMENT2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Emotion Detection Model**

# %% [markdown]
# ### **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.layers import Conv2D, Dense, BatchNormalization, Activation, Dropout, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from keras import regularizers
from keras.callbacks import ModelCheckpoint, CSVLogger, TensorBoard, EarlyStopping, ReduceLROnPlateau
import datetime
import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model

# %%
! pip install kaggle
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d msambare/fer2013
# Out:
# Downloading fer2013.zip to /content
#  55% 33.0M/60.3M [00:00<00:00, 147MB/s]
# 100% 60.3M/60.3M [00:00<00:00, 186MB/s]

# %%
# !unzip fer2013.zip

# %% [markdown]
# ### **Importing Dataset**

# %%
train_path="/content/train"
val_path= "/content/test"

# %% [markdown]
# ### **Creating Training and test sets**

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.3,
                                   horizontal_flip=True)

training_set = train_datagen.flow_from_directory(train_path,
                                                batch_size=64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory(val_path,
                                                batch_size=64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# ### **Defining Model**

# %%
def get_model(input_size, classes=7):
     #Initialising the CNN
    model = tf.keras.models.Sequential()   

    model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape =input_size))
    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(2, 2))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)))
    model.add(Conv2D(256, kernel_size=(3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.5))
    
    model.add(Dense(classes, activation='softmax'))

    #Compliling the model
    model.compile(optimizer=Adam(lr=0.0001, decay=1e-6), 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])
    return model

# %%
row, col = 48, 48
classes = 7
fernet = get_model((row,col,1), classes)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
fernet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        18496
#
#  batch_normalization (BatchN  (None, 48, 48, 64)       256
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 64)       0
#  )
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 22, 22, 256)       295168
#
#  batch_normalization_1 (Batc  (None, 22, 22, 256)      1024
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 11, 11, 256)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 11, 11, 256)       0
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 1024)              31720448
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 32,116,743
# Trainable params: 32,116,103
# Non-trainable params: 640
# _________________________________________________________________

# %%
plot_model(fernet, to_file='fernet.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### **Callbacks Function**

# %%
chk_path = 'ferNet.h5'
log_dir = "checkpoint/logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             moniter='val_loss')

earlystop = EarlyStopping(monitor='val_loss', 
                          min_delta=0, 
                          patience=3, 
                          verbose=1, 
                          restore_best_weights=True)
                        
reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.2, 
                              patience=6, 
                              verbose=1, 
                              min_delta=0.0001)


tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
csv_logger = CSVLogger('training.log')

callbacks = [checkpoint, reduce_lr, csv_logger]

# %% [markdown]
# ### **Training Model**

# %%
steps_per_epoch = training_set.n // training_set.batch_size
validation_steps = test_set.n // test_set.batch_size

hist = fernet.fit(x=training_set,
                 validation_data=test_set,
                 epochs=60,
                 callbacks=callbacks,
                 steps_per_epoch=steps_per_epoch,
                 validation_steps=validation_steps)
# Out:
# Epoch 1/60
# 448/448 [==============================] - ETA: 0s - loss: 4.2374 - accuracy: 0.2820
# Epoch 1: val_loss improved from inf to 9.23955, saving model to ferNet.h5
# 448/448 [==============================] - 41s 63ms/step - loss: 4.2374 - accuracy: 0.2820 - val_loss: 9.2395 - val_accuracy: 0.1836 - lr: 1.0000e-04
# Epoch 2/60
# 448/448 [==============================] - ETA: 0s - loss: 3.4628 - accuracy: 0.3439
# Epoch 2: val_loss improved from 9.23955 to 3.06402, saving model to ferNet.h5
# 448/448 [==============================] - 27s 60ms/step - loss: 3.4628 - accuracy: 0.3439 - val_loss: 3.0640 - val_accuracy: 0.4111 - lr: 1.0000e-04
# Epoch 3/60
# 448/448 [==============================] - ETA: 0s - loss: 2.9476 - accuracy: 0.3749
# Epoch 3: val_loss improved from 3.06402 to 2.64783, saving model to ferNet.h5
# 448/448 [==============================] - 27s 59ms/step - loss: 2.9476 - accuracy: 0.3749 - val_loss: 2.6478 - val_accuracy: 0.4194 - lr: 1.0000e-04
# Epoch 4/60
# 448/448 [==============================] - ETA: 0s - loss: 2.5359 - accuracy: 0.4099
# Epoch 4: val_loss improved from 2.64783 to 2.27555, saving model to ferNet.h5
# 448/448 [==============================] - 27s 60ms/step - loss: 2.5359 - accuracy: 0.4099 - val_loss: 2.2756 - val_accuracy: 0.4505 - lr: 1.0000e-04
# Epoch 5/60
# 448/448 [==============================] - ETA: 0s - loss: 2.2229 - accuracy: 0.4345
# Epoch 5: val_loss improved from 2.27555 to 1.97293, saving model to ferNet.h5
# 448/448 [==============================] - 27s 59ms/step - loss: 2.2229 - accuracy: 0.4345 - val_loss: 1.9729 - val_accuracy: 0.4908 - lr: 1.0000e-04
# Epoch 6/60
# 448/448 [==============================] - ETA: 0s - loss: 1.9898 - accuracy: 0.4508
# Epoch 6: val_loss improved from 1.97293 to 1.78996, saving model to ferNet.h5
# 448/448 [==============================] - 27s 60ms/step - loss: 1.9898 - accuracy: 0.4508 - val_loss: 1.7900 - val_accuracy: 0.5003 - lr: 1.0000e-04
# Epoch 7/60
# 448/448 [==============================] - ETA: 0s - loss: 1.8049 - accuracy: 0.4711
# Epoch 7: val_loss improved from 1.78996 to 1.62959, saving model to ferNet.h5
# 448/448 [==============================] - 27s 60ms/step - loss: 1.8049 - accuracy: 0.4711 - val_loss: 1.6296 - val_accuracy: 0.5173 - lr: 1.0000e-04
# Epoch 8/60
# 448/448 [==============================] - ETA: 0s - loss: 1.6682 - accuracy: 0.4916
# Epoch 8: val_loss improved from 1.62959 to 1.50439, saving model to ferNet.h5
# 448/448 [==============================] - 27s 60ms/step - loss: 1.6682 - accuracy: 0.4916 - val_loss: 1.5044 - val_accuracy: 0.5382 - lr: 1.0000e-04
# Epoch 9/60
# 448/448 [==============================] - ETA: 0s - loss: 1.5583 - accuracy: 0.5055
# Epoch 9: val_loss improved from 1.50439 to 1.46211, saving model to ferNet.h5
# 448/448 [==============================] - 27s 60ms/step - loss: 1.5583 - accuracy: 0.5055 - val_loss: 1.4621 - val_accuracy: 0.5253 - lr: 1.0000e-04
# Epoch 10/60
# 448/448 [==============================] - ETA: 0s - loss: 1.4731 - accuracy: 0.5205
# Epoch 10: val_loss improved from 1.46211 to 1.34739, saving model to ferNet.h5
# 448/448 [==============================] - 27s 60ms/step - loss: 1.4731 - accuracy: 0.5205 - val_loss: 1.3474 - val_accuracy: 0.5525 - lr: 1.0000e-04
# Epoch 11/60
# 448/448 [==============================] - ETA: 0s - loss: 1.4060 - accuracy: 0.5372
# Epoch 11: val_loss improved from 1.34739 to 1.31009, saving model to ferNet.h5
# 448/448 [==============================] - 27s 59ms/step - loss: 1.4060 - accuracy: 0.5372 - val_loss: 1.3101 - val_accuracy: 0.5579 - lr: 1.0000e-04
# Epoch 12/60
# 448/448 [==============================] - ETA: 0s - loss: 1.3485 - accuracy: 0.5484
# Epoch 12: val_loss improved from 1.31009 to 1.26268, saving model to ferNet.h5
# 448/448 [==============================] - 29s 64ms/step - loss: 1.3485 - accuracy: 0.5484 - val_loss: 1.2627 - val_accuracy: 0.5725 - lr: 1.0000e-04
# Epoch 13/60
# 448/448 [==============================] - ETA: 0s - loss: 1.3007 - accuracy: 0.5624
# Epoch 13: val_loss improved from 1.26268 to 1.21751, saving model to ferNet.h5
# 448/448 [==============================] - 27s 60ms/step - loss: 1.3007 - accuracy: 0.5624 - val_loss: 1.2175 - val_accuracy: 0.5891 - lr: 1.0000e-04
# Epoch 14/60
# 448/448 [==============================] - ETA: 0s - loss: 1.2548 - accuracy: 0.5712
# Epoch 14: val_loss improved from 1.21751 to 1.19805, saving model to ferNet.h5
# 448/448 [==============================] - 27s 59ms/step - loss: 1.2548 - accuracy: 0.5712 - val_loss: 1.1980 - val_accuracy: 0.5926 - lr: 1.0000e-04
# Epoch 15/60
# 448/448 [==============================] - ETA: 0s - loss: 1.2166 - accuracy: 0.5854
# Epoch 15: val_loss did not improve from 1.19805
# 448/448 [==============================] - 26s 57ms/step - loss: 1.2166 - accuracy: 0.5854 - val_loss: 1.2042 - val_accuracy: 0.5891 - lr: 1.0000e-04
# Epoch 16/60
# 448/448 [==============================] - ETA: 0s - loss: 1.1868 - accuracy: 0.5914
# Epoch 16: val_loss improved from 1.19805 to 1.19073, saving model to ferNet.h5
# 448/448 [==============================] - 27s 60ms/step - loss: 1.1868 - accuracy: 0.5914 - val_loss: 1.1907 - val_accuracy: 0.5933 - lr: 1.0000e-04
# Epoch 17/60
# 447/448 [============================>.] - ETA: 0s - loss: 1.1516 - accuracy: 0.6049
# Epoch 17: val_loss improved from 1.19073 to 1.15593, saving model to ferNet.h5
# 448/448 [==============================] - 27s 60ms/step - loss: 1.1514 - accuracy: 0.6048 - val_loss: 1.1559 - val_accuracy: 0.6024 - lr: 1.0000e-04
# Epoch 18/60
# 447/448 [============================>.] - ETA: 0s - loss: 1.1234 - accuracy: 0.6157
# Epoch 18: val_loss improved from 1.15593 to 1.12064, saving model to ferNet.h5
# 448/448 [==============================] - 27s 60ms/step - loss: 1.1233 - accuracy: 0.6156 - val_loss: 1.1206 - val_accuracy: 0.6164 - lr: 1.0000e-04
# Epoch 19/60
# 448/448 [==============================] - ETA: 0s - loss: 1.0985 - accuracy: 0.6255
# Epoch 19: val_loss did not improve from 1.12064
# 448/448 [==============================] - 25s 57ms/step - loss: 1.0985 - accuracy: 0.6255 - val_loss: 1.1254 - val_accuracy: 0.6140 - lr: 1.0000e-04
# Epoch 20/60
# 448/448 [==============================] - ETA: 0s - loss: 1.0699 - accuracy: 0.6363
# Epoch 20: val_loss did not improve from 1.12064
# 448/448 [==============================] - 26s 57ms/step - loss: 1.0699 - accuracy: 0.6363 - val_loss: 1.1314 - val_accuracy: 0.6155 - lr: 1.0000e-04
# Epoch 21/60
# 448/448 [==============================] - ETA: 0s - loss: 1.0437 - accuracy: 0.6444
# Epoch 21: val_loss improved from 1.12064 to 1.10890, saving model to ferNet.h5
# 448/448 [==============================] - 27s 59ms/step - loss: 1.0437 - accuracy: 0.6444 - val_loss: 1.1089 - val_accuracy: 0.6249 - lr: 1.0000e-04
# Epoch 22/60
# 448/448 [==============================] - ETA: 0s - loss: 1.0225 - accuracy: 0.6534
# Epoch 22: val_loss did not improve from 1.10890
# 448/448 [==============================] - 26s 57ms/step - loss: 1.0225 - accuracy: 0.6534 - val_loss: 1.1397 - val_accuracy: 0.6161 - lr: 1.0000e-04
# Epoch 23/60
# 448/448 [==============================] - ETA: 0s - loss: 1.0016 - accuracy: 0.6611
# Epoch 23: val_loss did not improve from 1.10890
# 448/448 [==============================] - 26s 57ms/step - loss: 1.0016 - accuracy: 0.6611 - val_loss: 1.1260 - val_accuracy: 0.6219 - lr: 1.0000e-04
# Epoch 24/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9829 - accuracy: 0.6706
# Epoch 24: val_loss improved from 1.10890 to 1.08887, saving model to ferNet.h5
# 448/448 [==============================] - 27s 60ms/step - loss: 0.9829 - accuracy: 0.6706 - val_loss: 1.0889 - val_accuracy: 0.6345 - lr: 1.0000e-04
# Epoch 25/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9635 - accuracy: 0.6781
# Epoch 25: val_loss did not improve from 1.08887
# 448/448 [==============================] - 26s 57ms/step - loss: 0.9635 - accuracy: 0.6781 - val_loss: 1.0991 - val_accuracy: 0.6385 - lr: 1.0000e-04
# Epoch 26/60
# 447/448 [============================>.] - ETA: 0s - loss: 0.9385 - accuracy: 0.6869
# Epoch 26: val_loss did not improve from 1.08887
# 448/448 [==============================] - 26s 57ms/step - loss: 0.9385 - accuracy: 0.6869 - val_loss: 1.1152 - val_accuracy: 0.6330 - lr: 1.0000e-04
# Epoch 27/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9200 - accuracy: 0.6914
# Epoch 27: val_loss did not improve from 1.08887
# 448/448 [==============================] - 26s 58ms/step - loss: 0.9200 - accuracy: 0.6914 - val_loss: 1.1120 - val_accuracy: 0.6313 - lr: 1.0000e-04
# Epoch 28/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9013 - accuracy: 0.6996
# Epoch 28: val_loss did not improve from 1.08887
# 448/448 [==============================] - 26s 58ms/step - loss: 0.9013 - accuracy: 0.6996 - val_loss: 1.0981 - val_accuracy: 0.6348 - lr: 1.0000e-04
# Epoch 29/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8811 - accuracy: 0.7073
# Epoch 29: val_loss did not improve from 1.08887
# 448/448 [==============================] - 26s 57ms/step - loss: 0.8811 - accuracy: 0.7073 - val_loss: 1.0948 - val_accuracy: 0.6427 - lr: 1.0000e-04
# Epoch 30/60
# 447/448 [============================>.] - ETA: 0s - loss: 0.8605 - accuracy: 0.7173
# Epoch 30: val_loss did not improve from 1.08887
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 448/448 [==============================] - 25s 57ms/step - loss: 0.8611 - accuracy: 0.7172 - val_loss: 1.1188 - val_accuracy: 0.6388 - lr: 1.0000e-04
# Epoch 31/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8049 - accuracy: 0.7359
# Epoch 31: val_loss did not improve from 1.08887
# 448/448 [==============================] - 25s 57ms/step - loss: 0.8049 - accuracy: 0.7359 - val_loss: 1.0917 - val_accuracy: 0.6539 - lr: 2.0000e-05
# Epoch 32/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7691 - accuracy: 0.7498
# Epoch 32: val_loss improved from 1.08887 to 1.08763, saving model to ferNet.h5
# 448/448 [==============================] - 27s 59ms/step - loss: 0.7691 - accuracy: 0.7498 - val_loss: 1.0876 - val_accuracy: 0.6542 - lr: 2.0000e-05
# Epoch 33/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7555 - accuracy: 0.7547
# Epoch 33: val_loss did not improve from 1.08763
# 448/448 [==============================] - 26s 58ms/step - loss: 0.7555 - accuracy: 0.7547 - val_loss: 1.0891 - val_accuracy: 0.6571 - lr: 2.0000e-05
# Epoch 34/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7399 - accuracy: 0.7640
# Epoch 34: val_loss did not improve from 1.08763
# 448/448 [==============================] - 29s 65ms/step - loss: 0.7399 - accuracy: 0.7640 - val_loss: 1.0956 - val_accuracy: 0.6597 - lr: 2.0000e-05
# Epoch 35/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7333 - accuracy: 0.7640
# Epoch 35: val_loss improved from 1.08763 to 1.08499, saving model to ferNet.h5
# 448/448 [==============================] - 27s 61ms/step - loss: 0.7333 - accuracy: 0.7640 - val_loss: 1.0850 - val_accuracy: 0.6603 - lr: 2.0000e-05
# Epoch 36/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7259 - accuracy: 0.7643
# Epoch 36: val_loss improved from 1.08499 to 1.07739, saving model to ferNet.h5
# 448/448 [==============================] - 27s 60ms/step - loss: 0.7259 - accuracy: 0.7643 - val_loss: 1.0774 - val_accuracy: 0.6586 - lr: 2.0000e-05
# Epoch 37/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7126 - accuracy: 0.7708
# Epoch 37: val_loss did not improve from 1.07739
# 448/448 [==============================] - 26s 58ms/step - loss: 0.7126 - accuracy: 0.7708 - val_loss: 1.0857 - val_accuracy: 0.6621 - lr: 2.0000e-05
# Epoch 38/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7039 - accuracy: 0.7730
# Epoch 38: val_loss did not improve from 1.07739
# 448/448 [==============================] - 26s 57ms/step - loss: 0.7039 - accuracy: 0.7730 - val_loss: 1.0939 - val_accuracy: 0.6621 - lr: 2.0000e-05
# Epoch 39/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7029 - accuracy: 0.7739
# Epoch 39: val_loss did not improve from 1.07739
# 448/448 [==============================] - 26s 57ms/step - loss: 0.7029 - accuracy: 0.7739 - val_loss: 1.0851 - val_accuracy: 0.6624 - lr: 2.0000e-05
# Epoch 40/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6841 - accuracy: 0.7787
# Epoch 40: val_loss did not improve from 1.07739
# 448/448 [==============================] - 26s 58ms/step - loss: 0.6841 - accuracy: 0.7787 - val_loss: 1.0950 - val_accuracy: 0.6600 - lr: 2.0000e-05
# Epoch 41/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6819 - accuracy: 0.7796
# Epoch 41: val_loss did not improve from 1.07739
# 448/448 [==============================] - 26s 58ms/step - loss: 0.6819 - accuracy: 0.7796 - val_loss: 1.1017 - val_accuracy: 0.6609 - lr: 2.0000e-05
# Epoch 42/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6707 - accuracy: 0.7867
# Epoch 42: val_loss did not improve from 1.07739
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 448/448 [==============================] - 26s 58ms/step - loss: 0.6707 - accuracy: 0.7867 - val_loss: 1.0922 - val_accuracy: 0.6641 - lr: 2.0000e-05
# Epoch 43/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6596 - accuracy: 0.7895
# Epoch 43: val_loss did not improve from 1.07739
# 448/448 [==============================] - 26s 58ms/step - loss: 0.6596 - accuracy: 0.7895 - val_loss: 1.1029 - val_accuracy: 0.6645 - lr: 4.0000e-06
# Epoch 44/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6525 - accuracy: 0.7907
# Epoch 44: val_loss did not improve from 1.07739
# 448/448 [==============================] - 26s 58ms/step - loss: 0.6525 - accuracy: 0.7907 - val_loss: 1.1004 - val_accuracy: 0.6652 - lr: 4.0000e-06
# Epoch 45/60
# 447/448 [============================>.] - ETA: 0s - loss: 0.6523 - accuracy: 0.7899
# Epoch 45: val_loss did not improve from 1.07739
# 448/448 [==============================] - 26s 58ms/step - loss: 0.6522 - accuracy: 0.7899 - val_loss: 1.0999 - val_accuracy: 0.6659 - lr: 4.0000e-06
# Epoch 46/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6500 - accuracy: 0.7917
# Epoch 46: val_loss did not improve from 1.07739
# 448/448 [==============================] - 26s 58ms/step - loss: 0.6500 - accuracy: 0.7917 - val_loss: 1.1058 - val_accuracy: 0.6659 - lr: 4.0000e-06
# Epoch 47/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6503 - accuracy: 0.7942
# Epoch 47: val_loss did not improve from 1.07739
# 448/448 [==============================] - 30s 66ms/step - loss: 0.6503 - accuracy: 0.7942 - val_loss: 1.1103 - val_accuracy: 0.6645 - lr: 4.0000e-06
# Epoch 48/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6432 - accuracy: 0.7969
# Epoch 48: val_loss did not improve from 1.07739
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 448/448 [==============================] - 26s 58ms/step - loss: 0.6432 - accuracy: 0.7969 - val_loss: 1.1020 - val_accuracy: 0.6656 - lr: 4.0000e-06
# Epoch 49/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6421 - accuracy: 0.7969
# Epoch 49: val_loss did not improve from 1.07739
# 448/448 [==============================] - 26s 59ms/step - loss: 0.6421 - accuracy: 0.7969 - val_loss: 1.1057 - val_accuracy: 0.6650 - lr: 8.0000e-07
# Epoch 50/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6456 - accuracy: 0.7947
# Epoch 50: val_loss did not improve from 1.07739
# 448/448 [==============================] - 25s 57ms/step - loss: 0.6456 - accuracy: 0.7947 - val_loss: 1.1011 - val_accuracy: 0.6670 - lr: 8.0000e-07
# Epoch 51/60
# 447/448 [============================>.] - ETA: 0s - loss: 0.6468 - accuracy: 0.7933
# Epoch 51: val_loss did not improve from 1.07739
# 448/448 [==============================] - 26s 57ms/step - loss: 0.6466 - accuracy: 0.7933 - val_loss: 1.1019 - val_accuracy: 0.6652 - lr: 8.0000e-07
# Epoch 52/60
# 447/448 [============================>.] - ETA: 0s - loss: 0.6422 - accuracy: 0.7951
# Epoch 52: val_loss did not improve from 1.07739
# 448/448 [==============================] - 25s 57ms/step - loss: 0.6424 - accuracy: 0.7950 - val_loss: 1.1007 - val_accuracy: 0.6669 - lr: 8.0000e-07
# Epoch 53/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6308 - accuracy: 0.8008
# Epoch 53: val_loss did not improve from 1.07739
# 448/448 [==============================] - 26s 58ms/step - loss: 0.6308 - accuracy: 0.8008 - val_loss: 1.1053 - val_accuracy: 0.6667 - lr: 8.0000e-07
# Epoch 54/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6368 - accuracy: 0.7974
# Epoch 54: val_loss did not improve from 1.07739
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# 448/448 [==============================] - 25s 57ms/step - loss: 0.6368 - accuracy: 0.7974 - val_loss: 1.1047 - val_accuracy: 0.6650 - lr: 8.0000e-07
# Epoch 55/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6375 - accuracy: 0.7974
# Epoch 55: val_loss did not improve from 1.07739
# 448/448 [==============================] - 27s 59ms/step - loss: 0.6375 - accuracy: 0.7974 - val_loss: 1.1038 - val_accuracy: 0.6649 - lr: 1.6000e-07
# Epoch 56/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6355 - accuracy: 0.7983
# Epoch 56: val_loss did not improve from 1.07739
# 448/448 [==============================] - 26s 59ms/step - loss: 0.6355 - accuracy: 0.7983 - val_loss: 1.1040 - val_accuracy: 0.6645 - lr: 1.6000e-07
# Epoch 57/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6389 - accuracy: 0.7951
# Epoch 57: val_loss did not improve from 1.07739
# 448/448 [==============================] - 26s 58ms/step - loss: 0.6389 - accuracy: 0.7951 - val_loss: 1.1038 - val_accuracy: 0.6650 - lr: 1.6000e-07
# Epoch 58/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6390 - accuracy: 0.7989
# Epoch 58: val_loss did not improve from 1.07739
# 448/448 [==============================] - 26s 58ms/step - loss: 0.6390 - accuracy: 0.7989 - val_loss: 1.1029 - val_accuracy: 0.6655 - lr: 1.6000e-07
# Epoch 59/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6357 - accuracy: 0.7977
# Epoch 59: val_loss did not improve from 1.07739
# 448/448 [==============================] - 26s 59ms/step - loss: 0.6357 - accuracy: 0.7977 - val_loss: 1.1041 - val_accuracy: 0.6650 - lr: 1.6000e-07
# Epoch 60/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6341 - accuracy: 0.7989
# Epoch 60: val_loss did not improve from 1.07739
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 3.199999980552093e-08.
# 448/448 [==============================] - 26s 57ms/step - loss: 0.6341 - accuracy: 0.7989 - val_loss: 1.1038 - val_accuracy: 0.6653 - lr: 1.6000e-07

# %% [markdown]
# ### **Loss Accurancy Plot**

# %%
plt.figure(figsize=(14,5))
plt.subplot(1,2,2)
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['train', 'test'], loc='upper left')

plt.subplot(1,2,1)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# high accracy is achieved on training set but accuracy on validation set is stuck at 66% also no overfitting can se seen in the dataset hence is can be concluded that the inefficiency may be due to the unbalanced dataset

# %% [markdown]
# ### **Model evaluation**

# %%
train_loss, train_accu = fernet.evaluate(training_set)
test_loss, test_accu = fernet.evaluate(test_set)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 449/449 [==============================] - 19s 42ms/step - loss: 0.4773 - accuracy: 0.8698
# 113/113 [==============================] - 2s 22ms/step - loss: 1.1034 - accuracy: 0.6654
# final train accuracy = 86.98 , validation accuracy = 66.54
